# %%
print("Hello World!")
# Out:
# Hello World!

# %%
# Sequential
angka = 10

hasil = angka * 20

print(hasil)
# Out:
# 200

# %%
# Selection
angka = 20

cek_angka = angka % 2

if cek_angka == 0:
    print("Genap")
else:
    print("Ganjil")
# Out:
# Genap
